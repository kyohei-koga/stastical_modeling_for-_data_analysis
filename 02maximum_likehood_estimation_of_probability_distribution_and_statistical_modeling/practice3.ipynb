# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import rpy2.robjects as robjects
import readline
from scipy import stats
# %matplotlib inline

# %%
robjects.r['load']('data.RData')
data = pd.Series(np.array(robjects.r['data']))

# %%
data.head()
# Out:
# 0    2.0
# 1    2.0
# 2    4.0
# 3    6.0
# 4    4.0
# dtype: float64

# %%
len(data)
# Out:
# 50

# %%
data.describe()
# Out:
# count    50.00000
# mean      3.56000
# std       1.72804
# min       0.00000
# 25%       2.00000
# 50%       3.00000
# 75%       4.75000
# max       7.00000
# dtype: float64

# %%
plt.hist(data,bins=np.arange(-0.5,8.5,1.))
# Out:
# (array([  1.,   3.,  11.,  12.,  10.,   5.,   4.,   4.]),
#  array([-0.5,  0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5]),
#  <a list of 8 Patch objects>)

# %%
data.var()
# Out:
# 2.986122448979592

# %%
data.std()
# Out:
# 1.728040060004279

# %%
x = np.arange(0,10)
prob = pd.Series(stats.poisson.pmf(x,3.56),index=x)
prob
# Out:
# 0    0.028439
# 1    0.101242
# 2    0.180211
# 3    0.213851
# 4    0.190327
# 5    0.135513
# 6    0.080404
# 7    0.040891
# 8    0.018197
# 9    0.007198
# dtype: float64

# %%
plt.plot(prob,'o--')

# %%
plt.plot(prob*50,'o--')
plt.hist(data,bins=np.arange(-0.5,8.5,1.))
# Out:
# (array([  1.,   3.,  11.,  12.,  10.,   5.,   4.,   4.]),
#  array([-0.5,  0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5]),
#  <a list of 8 Patch objects>)

# %%
x = np.arange(0,20)
plt.plot(x,stats.poisson.pmf(x,3.5),'o--',label=3.5)
plt.plot(x,stats.poisson.pmf(x,7.7),'D--',label=7.7)
plt.plot(x,stats.poisson.pmf(x,15.1),'^--',label=15.1)
plt.legend(loc='upper right')
plt.xlabel('x')
plt.ylabel('prob')

# %%
t_lambda=[2.0,2.4,2.8,3.2,3.6,4.0,4.4,4.8,5.2]
pieces = []
x = np.arange(0,10)
for lam in t_lambda:
    distribution = pd.Series(stats.poisson.pmf(x,lam),name='lambda_%.1f' %lam)*50
    pieces.append(distribution)

# %%
dd = pd.concat(pieces,axis=1)

# %%
dd.head()
# Out:
#    lambda_2.0  lambda_2.4  lambda_2.8  lambda_3.2  lambda_3.6  lambda_4.0  \
# 0    6.766764    4.535898    3.040503    2.038110    1.366186    0.915782
# 1   13.533528   10.886154    8.513409    6.521953    4.918270    3.663128
# 2   13.533528   13.063385   11.918772   10.435124    8.852886    7.326256
# 3    9.022352   10.450708   11.124187   11.130799   10.623463    9.768341
# 4    4.511176    6.270425    7.786931    8.904639    9.561117    9.768341
#
#    lambda_4.4  lambda_4.8  lambda_5.2
# 0    0.613867    0.411487    0.275828
# 1    2.701015    1.975139    1.434307
# 2    5.942233    4.740334    3.729198
# 3    8.715274    7.584535    6.463942
# 4    9.586802    9.101442    8.403125

# %%
import itertools
fig,axes = plt.subplots(3,3,figsize=(15,15))

for i,j in enumerate(itertools.product(range(3),range(3))):
    log_likelihood = np.sum(stats.poisson.logpmf(data,t_lambda[i]))
    dd['lambda_%.1f'%t_lambda[i]].plot(style='o--',label='lambda%.1f'%t_lambda[i],ax=axes[j[0]][j[1]])
    axes[j[0]][j[1]].hist(data,bins=np.arange(-0.5,8.5,1.),label='logL=%.1f'%log_likelihood)
    axes[j[0]][j[1]].legend(loc='upper right')

# %%
x = np.arange(2.0,5.0,0.01)
logL = np.array([sum(stats.poisson.logpmf(data,i)) for i in x])
plt.plot(x,logL)
plt.axvline(x=x[np.argmax(logL)],c='r')
plt.xlabel('lambda')
plt.ylabel('logL')
print(x[np.argmax(logL)])
# Out:
# 3.56

# %%
likelihoods = []
for j in range(3000):
    data_a = np.random.poisson(3.5,50)
    x = np.arange(2.0,5.0,0.01)
    logL = np.array([sum(stats.poisson.logpmf(data_a,i)) for i in x])
    likelihoods.append(x[np.argmax(logL)])

# %%
plt.hist(likelihoods,bins=np.arange(2.5,4.5,0.1))
plt.xlabel('value of likeliwood')
