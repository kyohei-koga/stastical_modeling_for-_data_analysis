# %%
# %matplotlib inline
import readline #rpy2使うときはとりあえず入れとく。
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import rpy2.robjects as robjects
from scipy import stats

# %% [markdown]
# Rオブジェクトの読み込み
#
# 種子数$y_{i}$の読み込み

# %%
robjects.r['load']('data.RData')
data = pd.Series(np.array(robjects.r['data']))

# %%
print data.head(3)
# Out:
# 0    2.0
# 1    2.0
# 2    4.0
# dtype: float64

# %% [markdown]
# データ数の確認

# %%
len(data)
# Out:
# 50

# %% [markdown]
# 要約統計

# %%
data.describe()
# Out:
# count    50.00000
# mean      3.56000
# std       1.72804
# min       0.00000
# 25%       2.00000
# 50%       3.00000
# 75%       4.75000
# max       7.00000
# dtype: float64

# %% [markdown]
# データ解析で重要なことは、いろいろな方法でとにかく図示してみることです。
#
# ヒストグラムの作成

# %%
plt.hist(data,bins=np.arange(-0.5,8.5,1.0)) #ビンの位置を指定している。
plt.show()

# %% [markdown]
# 標本分散の計算

# %%
data.var()
# Out:
# 2.986122448979592

# %% [markdown]
# 標本標準偏差の計算

# %%
print np.sqrt(data.var()),data.std()
# Out:
# 1.72804006 1.72804006

# %% [markdown]
# ポアソン分布の作図
#
# ポアソン分布が指定できるパラメータは平均値のひとつだけ

# %% [markdown]
# 使うデータの特徴
#
# - 1個、２個と数えることのできるデータ
# - １個体の種子数の標本平均は3.56個
# - 個体ごとの種子数にはばらつきがあり、ヒストグラムを描くとひと山の分布になる

# %%
x = np.arange(0,10)
prob = pd.Series(stats.poisson.pmf(x,3.56),index=x)
print prob
# Out:
# 0    0.028439
# 1    0.101242
# 2    0.180211
# 3    0.213851
# 4    0.190327
# 5    0.135513
# 6    0.080404
# 7    0.040891
# 8    0.018197
# 9    0.007198
# dtype: float64

# %%
plt.plot(prob,'o--')
plt.show()

# %% [markdown]
# 観測データとの重ねあわせ

# %%
plt.plot(prob*50,'o--')
plt.hist(data,bins=np.arange(-0.5,8.5,1.0))
plt.show()

# %% [markdown]
# ポアソン分布の定義
# $$p(x|\lambda) = \frac{\lambda^x \exp(-\lambda)}{x!}$$
#
# - 確率変数は0以上の値をとる
# - 確率分布の平均は$\lambda$である
# - 分散と平均は等しい
#
#
# 先のデータにポアソン分布をフィットさせる理由は
# - データが非負の整数であること
# - 観測データの平均と分散が大体等しい
#
# ポアソン分布のλを変えると以下のように、分布が変化する。

# %%
x = np.arange(0,20)
plt.plot(pd.Series(stats.poisson.pmf(x,3.5),index=x),'o--',label=3.5)
plt.plot(pd.Series(stats.poisson.pmf(x,7.7),index=x),'D--',label=7.7)
plt.plot(pd.Series(stats.poisson.pmf(x,15.1),index=x),'^--',label=15.1)
plt.legend(loc='upper right',title='lambda')
plt.xlabel('x')
plt.ylabel('prob')
plt.show()

# %% [markdown]
# ### ポアソン分布のパラメータの最尤推定
# 最尤推定法は尤度なる「当てはまりの良さ」を表す統計量を最大にするようなパラメータの値を探そうとするパラメータ推定法です。
#
# 尤度の実態はある$\lambda$の値を決めた時に、すべての個体iについての$p(y_{i}|\lambda)$の積です。
#
# なぜ積かというとy1が２である、かつ、y2が2であるかつ・・・と50個の事象が同時に真である確率を計算したいからである。

# %%
#様々なパラメータごとのポアソン分布と、観測データの分布を重ねる。
#対数尤度も計算して、対数尤度が一番小さいグラフの観測と理論の類似度を観察する。
t_lambda = [2.0,2.4,2.8,3.2,3.6,4.0,4.4,4.8,5.2]

# %%
pieces = []
x = np.arange(0,10)
for lam in t_lambda:
    distribution = pd.Series(stats.poisson.pmf(x,lam),index=x,name='lambda_%s'%lam)*50 
    pieces.append(distribution)

# %%
dd = pd.concat(pieces,axis=1)

# %%
dd.head()
# Out:
#    lambda_2.0  lambda_2.4  lambda_2.8  lambda_3.2  lambda_3.6  lambda_4.0  \
# 0    6.766764    4.535898    3.040503    2.038110    1.366186    0.915782
# 1   13.533528   10.886154    8.513409    6.521953    4.918270    3.663128
# 2   13.533528   13.063385   11.918772   10.435124    8.852886    7.326256
# 3    9.022352   10.450708   11.124187   11.130799   10.623463    9.768341
# 4    4.511176    6.270425    7.786931    8.904639    9.561117    9.768341
#
#    lambda_4.4  lambda_4.8  lambda_5.2
# 0    0.613867    0.411487    0.275828
# 1    2.701015    1.975139    1.434307
# 2    5.942233    4.740334    3.729198
# 3    8.715274    7.584535    6.463942
# 4    9.586802    9.101442    8.403125

# %% [markdown]
# $\lambda$が3.6の時対数尤度が最大で、標本分布と綺麗に一致している。

# %%
import itertools
fig,axes = plt.subplots(3,3,figsize=(15,15))
for i,j in enumerate(itertools.product(range(3),range(3))):
    log_likelihood = np.sum(stats.poisson.logpmf(data,t_lambda[i]))
    dd['lambda_%.1f'%t_lambda[i]].plot(style='--o',label='lambda%.1f' %t_lambda[i],ax=axes[j[0]][j[1]])
    axes[j[0]][j[1]].hist(data,bins=np.arange(-0.5,8.5,1.0),label='log L=%.1f'%log_likelihood)
    axes[j[0]][j[1]].legend(loc='upper right')
    axes[j[0]][j[1]].set_xlim((-2,10))
plt.show()

# %% [markdown]
# 尤度の最大値を求める
#
# 対数ゆうど関数を$\lambda$で偏微分して、0になる$\lambda$がほしいパラメータ。

# %%
x = np.arange(2.0,5.0,0.01)
logL = np.array([sum(stats.poisson.logpmf(data,i)) for i in x]) #lambda(=i)毎の尤度
plt.plot(x,logL)
plt.axvline(x=x[np.argmax(logL)],color='red')
plt.xlabel('lambda')
plt.ylabel('logL')
plt.show()
print("最大尤度：%.1f" % x[np.argmax(logL)])
# Out:
# 最大尤度：3.6

# %% [markdown]
# ### 最大尤度の分布
# 平均3.5のポアソン分布に従う乱数50個の集団を、3000回発生させて、毎回最大尤度を計算し、最大尤度の分布を見る。

# %%
likewoods = []
for j in range(3000): 
    data_a = np.random.poisson(3.5,50)
    x = np.arange(2.0,5.0,0.01) #lambda
    logL = np.array([sum(stats.poisson.logpmf(data_a,i)) for i in x])
    likewoods.append(x[np.argmax(logL)])

# %%
plt.hist(likewoods,bins=np.arange(2.5,4.5,0.1))
plt.xlabel('value of likewood')
plt.show()

# %% [markdown]
# 確率分布の選び方
# - 説明したい量は離散か連続化？
# - 説明したい量の範囲は?
# - 説明したい量の標本分散と標本平均の関係は
