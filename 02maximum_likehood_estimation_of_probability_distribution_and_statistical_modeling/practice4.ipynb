# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import rpy2.robjects as robjects
import readline
# %matplotlib inline

# %%
robjects.r['load']('data.RData')
data = pd.Series(np.array(robjects.r['data']))

# %%
data.head()
# Out:
# 0    2.0
# 1    2.0
# 2    4.0
# 3    6.0
# 4    4.0
# dtype: float64

# %%
len(data)
# Out:
# 50

# %%
data.describe()
# Out:
# count    50.00000
# mean      3.56000
# std       1.72804
# min       0.00000
# 25%       2.00000
# 50%       3.00000
# 75%       4.75000
# max       7.00000
# dtype: float64

# %%
data.plot(kind='hist',bins=np.arange(-0.5,8.5,1.0))

# %%
data.var()
# Out:
# 2.986122448979592

# %%
data.std()
# Out:
# 1.728040060004279

# %%
x = np.arange(0,10)
prob = pd.Series(stats.poisson.pmf(x,3.56),index=x)

# %%
prob
# Out:
# 0    0.028439
# 1    0.101242
# 2    0.180211
# 3    0.213851
# 4    0.190327
# 5    0.135513
# 6    0.080404
# 7    0.040891
# 8    0.018197
# 9    0.007198
# dtype: float64

# %%
plt.plot(prob,'o--')

# %%
plt.plot(prob*50,'o--')
data.plot(kind='hist',bins=np.arange(-0.5,8.5))

# %%
x = np.arange(0,20)
plt.plot(pd.Series(stats.poisson.pmf(x,3.5),index=x),'o--')
plt.plot(pd.Series(stats.poisson.pmf(x,7.7),index=x),'D--')
plt.plot(pd.Series(stats.poisson.pmf(x,15.1),index=x),'^--')

# %%
t_lambda = [2.0,2.4,2.8,3.2,3.6,4.0,4.4,4.8,5.2]

# %%
pieces = []
x = np.arange(0,10)
for lam in t_lambda:
    distribution = pd.Series(stats.poisson.pmf(x,lam),index=x,name='lambda\_s',%lam)*50
    pieces.append()
# Out:
#   File "<ipython-input-28-2fe94e67567e>", line 4
#     distribution = pd.Series(stats.poisson.pmf(x,lam),index=x,name='lambda\_s',%lam)*50
#                                                                                ^
# SyntaxError: invalid syntax
